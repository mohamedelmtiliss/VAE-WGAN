# %%
import ee
import pandas as pd
import requests
import os
import time
from datetime import datetime, timedelta
import glob
# Out:
# c:\Users\Demahom\.conda\envs\VAE-WGAN\lib\site-packages\google\api_core\_python_version_support.py:275: FutureWarning: You are using a Python version (3.10.19) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)

# %%
# ==========================================
# 1. INITIALIZATION & CONFIGURATION
# ==========================================

# Initialize Earth Engine
try:
    ee.Initialize(project='vae-wgan')
except Exception as e:
    print("Authenticating Earth Engine...")
    ee.Authenticate()
    ee.Initialize()

# %%
# Configuration
CSV_FILE = "./modis_2024_Brazil.csv"  # CHANGE THIS to your actual filename
OUTPUT_DIR = 'modis_dataset_brazil'
FIRE_DIR = os.path.join(OUTPUT_DIR, 'fire_anomalies')
NORMAL_DIR = os.path.join(OUTPUT_DIR, 'normal_reference')

# Image Settings
IMG_SIZE = 64        # Input size for VAE (64x64 pixels)
SCALE = 500          # MODIS resolution (500 meters per pixel)
ROI_RADIUS = (IMG_SIZE * SCALE) / 2  # Radius in meters to get the correct crop

# MODIS Collection (Terra Surface Reflectance)
MODIS_COLLECTION = 'MODIS/061/MOD09GA'

# Create directories
os.makedirs(FIRE_DIR, exist_ok=True)
os.makedirs(NORMAL_DIR, exist_ok=True)

# %%
# ==========================================
# 2. HELPER FUNCTIONS
# ==========================================

def get_cloud_percentage(image, region):
    """
    Calculates the percentage of cloudy pixels in the given region
    using the 'state_1km' QA band.
    """
    try:
        qa = image.select('state_1km')

        # Bits 0-1: Cloud state (00=Clear, 01=Cloudy, 10=Mixed, 11=Not set)
        # We perform bitwise AND with 3 (binary 11) to isolate these bits.
        cloud_state = qa.bitwiseAnd(3)

        # Mask where value is 1 (Cloudy) or 2 (Mixed)
        is_cloudy = cloud_state.eq(1).Or(cloud_state.eq(2))

        # Calculate mean (percentage) of cloudy pixels
        cloud_stats = is_cloudy.reduceRegion(
            reducer=ee.Reducer.mean(),
            geometry=region,
            scale=SCALE,
            maxPixels=1e9
        )

        pct = cloud_stats.get('state_1km').getInfo()
        return pct * 100 if pct is not None else 100
    except Exception as e:
        print(f"Error checking clouds: {e}")
        return 100.0  # Assume cloudy if error

# %%
def get_clear_image(lat, lon, target_date_str, search_window_days=14):
    """
    Searches for a clear image (<10% clouds) around the target date.
    Returns: (ee.Image object, actual_date_string) or (None, None)
    """
    target_dt = datetime.strptime(target_date_str, '%Y-%m-%d')
    point = ee.Geometry.Point([lon, lat])
    region = point.buffer(ROI_RADIUS).bounds()

    start_search = (target_dt - timedelta(days=search_window_days)).strftime('%Y-%m-%d')
    end_search = (target_dt + timedelta(days=search_window_days)).strftime('%Y-%m-%d')

    # Get collection sorted by time
    collection = (ee.ImageCollection(MODIS_COLLECTION)
                  .filterDate(start_search, end_search)
                  .filterBounds(point))

    # Get list of images (Client-side iteration required for logic)
    # We limit to 20 images to prevent timeouts
    img_list_size = collection.size().getInfo()
    if img_list_size == 0:
        return None, None

    ee_list = collection.toList(min(img_list_size, 20))
    count = ee_list.size().getInfo()

    for i in range(count):
        img = ee.Image(ee_list.get(i))

        # Check Cloud Cover
        cloud_pct = get_cloud_percentage(img, region)

        if cloud_pct < 10.0:  # Strict threshold: < 10% clouds
            date_found = ee.Date(img.get('system:time_start')).format('YYYY-MM-dd').getInfo()
            return img, date_found

    return None, None

# %%
def download_image(ee_image, region, output_path):
    """
    Generates a URL and downloads the image.
    """
    if os.path.exists(output_path):
        print(f"Skipping (Exists): {os.path.basename(output_path)}")
        return

    # Visualization: Band 7 (SWIR-Heat), Band 2 (NIR-Veg), Band 1 (Red)
    vis_params = {
        'min': -100.0,
        'max': 8000.0,
        'bands': ['sur_refl_b07', 'sur_refl_b02', 'sur_refl_b01'],
    }

    try:
        url = ee_image.getThumbURL({
            'region': region,
            'dimensions': f'{IMG_SIZE}x{IMG_SIZE}',
            'format': 'png',
            **vis_params
        })

        response = requests.get(url, timeout=1)
        if response.status_code == 200:
            with open(output_path, 'wb') as f:
                f.write(response.content)
            print(f"Saved: {os.path.basename(output_path)}") # Optional: quiet mode
        else:
            print(f"Failed to download (Status {response.status_code})")

    except Exception as e:
        print(f"Download Error: {e}")

# %%
def get_existing_indices(directory, prefix):
    """
    Scans the directory and returns a set of indices that are already downloaded.
    Filename format expected: prefix_{index}_{date}.png
    """
    existing = set()
    # Pattern to match: prefix_NUMBER_*.png
    # We use glob to find all files matching the pattern
    files = glob.glob(os.path.join(directory, f"{prefix}_*.png"))
    
    for f in files:
        try:
            # Extract the filename only
            filename = os.path.basename(f)
            # Split by '_' and get the index (2nd part: prefix_INDEX_date.png)
            parts = filename.split('_')
            if len(parts) >= 2:
                idx = int(parts[1])
                existing.add(idx)
        except ValueError:
            continue # Skip files that don't match the format
            
    return existing

# %%
def main():
    # 1. Load Data
    if not os.path.exists(CSV_FILE):
        print(f"ERROR: File {CSV_FILE} not found.")
        return

    df = pd.read_csv(CSV_FILE)
    
    # Filter Confidence > 80
    if 'confidence' in df.columns:
        df = df[df['confidence'] > 80]
    elif 'confidence_perc' in df.columns:
        df = df[df['confidence_perc'] > 80]
        
    # Reset index so we have a consistent ID (0, 1, 2...) for filenames
    # IMPORTANT: We do NOT shuffle here if we want to resume reliably, 
    # OR we must ensure the shuffle is deterministic (random_state=42).
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    
    print(f"Total target images to download: {len(df)}")

    # 2. FAST RESUME: Scan folders once
    print("Scanning existing files to skip...")
    existing_fire = get_existing_indices(FIRE_DIR, "fire")
    existing_normal = get_existing_indices(NORMAL_DIR, "normal")
    
    print(f"Found {len(existing_fire)} existing Fire images.")
    print(f"Found {len(existing_normal)} existing Normal images.")

    print("\nStarting download process... (Press Ctrl+C to stop)")
    
    success_fire = 0
    success_normal = 0

    for index, row in df.iterrows():
        try:
            # --- INSTANT SKIP CHECK ---
            # If we have BOTH files for this index, skip entirely.
            # No Earth Engine calls, no delay.
            if (index in existing_fire) and (index in existing_normal):
                continue 

            lat = row['latitude']
            lon = row['longitude']
            fire_date = row['acq_date']
            
            # --- 1. DOWNLOAD FIRE ANOMALY ---
            if index not in existing_fire:
                point = ee.Geometry.Point([lon, lat])
                region = point.buffer(ROI_RADIUS).bounds()
                
                fire_img = (ee.ImageCollection(MODIS_COLLECTION)
                            .filterDate(fire_date, datetime.strptime(fire_date, '%Y-%m-%d') + timedelta(days=1))
                            .filterBounds(point)
                            .first())
                
                # Check if exists on server (using .getInfo usually needed for None check, 
                # but we'll try/except the download to keep it fast)
                fire_out = os.path.join(FIRE_DIR, f"fire_{index}_{fire_date}.png")
                
                # Only run download if we verified we don't have it
                download_image(fire_img, region, fire_out)
                success_fire += 1
                
                # Rate limit slightly after a download
                time.sleep(0.1)

            # --- 2. DOWNLOAD NORMAL REFERENCE ---
            if index not in existing_normal:
                point = ee.Geometry.Point([lon, lat])
                region = point.buffer(ROI_RADIUS).bounds()
                
                fire_dt = datetime.strptime(fire_date, '%Y-%m-%d')
                ideal_date = (fire_dt - timedelta(days=365)).strftime('%Y-%m-%d')
                
                # Only NOW do we ask Google for the cloud-free date
                normal_img, normal_date_found = get_clear_image(lat, lon, ideal_date)
                
                if normal_img:
                    normal_out = os.path.join(NORMAL_DIR, f"normal_{index}_{normal_date_found}.png")
                    download_image(normal_img, region, normal_out)
                    success_normal += 1
                    print(f"[{index}] Downloaded Pair (Fire: {fire_date} | Normal: {normal_date_found})")
                else:
                    print(f"[{index}] Skipped Normal: Too cloudy")
                
                # Rate limit after an API-heavy search
                time.sleep(0.5)

        except KeyboardInterrupt:
            print("\nStopping download...")
            break
        except Exception as e:
            print(f"[{index}] Error: {e}")
            continue

    print(f"\nSession Finished.")
    print(f"New Fire Images: {success_fire}")
    print(f"New Normal Images: {success_normal}")

# %%
if __name__ == "__main__":
    main()
# Out:
# Total target images to download: 191698
# Scanning existing files to skip...
# Found 6738 existing Fire images.
# Found 6402 existing Normal images.
#
# Starting download process... (Press Ctrl+C to stop)
# [10] Skipped Normal: Too cloudy
# [29] Skipped Normal: Too cloudy
# [37] Skipped Normal: Too cloudy
# [38] Skipped Normal: Too cloudy
# [62] Skipped Normal: Too cloudy
# [128] Skipped Normal: Too cloudy
# [136] Skipped Normal: Too cloudy
# [158] Skipped Normal: Too cloudy
# [171] Skipped Normal: Too cloudy
# [185] Skipped Normal: Too cloudy
# [205] Skipped Normal: Too cloudy
# [213] Skipped Normal: Too cloudy
# [215] Skipped Normal: Too cloudy
# [252] Skipped Normal: Too cloudy
# [279] Skipped Normal: Too cloudy
# [295] Skipped Normal: Too cloudy
# [322] Skipped Normal: Too cloudy
# [332] Skipped Normal: Too cloudy
# [346] Skipped Normal: Too cloudy
# [351] Skipped Normal: Too cloudy
# [379] Skipped Normal: Too cloudy
# [387] Skipped Normal: Too cloudy
# [446] Skipped Normal: Too cloudy
# [453] Skipped Normal: Too cloudy
# [484] Skipped Normal: Too cloudy
# [500] Skipped Normal: Too cloudy
# [505] Skipped Normal: Too cloudy
# [510] Skipped Normal: Too cloudy
# [542] Skipped Normal: Too cloudy
# [545] Skipped Normal: Too cloudy
# [596] Skipped Normal: Too cloudy
# [599] Skipped Normal: Too cloudy
# [633] Skipped Normal: Too cloudy
# [639] Skipped Normal: Too cloudy
# [644] Skipped Normal: Too cloudy
# [662] Skipped Normal: Too cloudy
# [667] Skipped Normal: Too cloudy
# [674] Skipped Normal: Too cloudy
# [681] Skipped Normal: Too cloudy
# [699] Skipped Normal: Too cloudy
# [706] Skipped Normal: Too cloudy
# [729] Skipped Normal: Too cloudy
# [822] Skipped Normal: Too cloudy
# [870] Skipped Normal: Too cloudy
# [884] Skipped Normal: Too cloudy
# [903] Skipped Normal: Too cloudy
# [942] Skipped Normal: Too cloudy
# [971] Skipped Normal: Too cloudy
# [979] Skipped Normal: Too cloudy
# [983] Skipped Normal: Too cloudy
# [986] Skipped Normal: Too cloudy
# [991] Skipped Normal: Too cloudy
# [1008] Skipped Normal: Too cloudy
# [1013] Skipped Normal: Too cloudy
# [1030] Skipped Normal: Too cloudy
# [1068] Skipped Normal: Too cloudy
# [1069] Skipped Normal: Too cloudy
# [1149] Skipped Normal: Too cloudy
# [1193] Skipped Normal: Too cloudy
# [1217] Skipped Normal: Too cloudy
# [1218] Skipped Normal: Too cloudy
# [1254] Skipped Normal: Too cloudy
# [1261] Skipped Normal: Too cloudy
# [1263] Skipped Normal: Too cloudy
# [1292] Skipped Normal: Too cloudy
# [1328] Skipped Normal: Too cloudy
# [1347] Skipped Normal: Too cloudy
# [1362] Skipped Normal: Too cloudy
# [1379] Skipped Normal: Too cloudy
# [1385] Skipped Normal: Too cloudy
# [1403] Skipped Normal: Too cloudy
# [1431] Skipped Normal: Too cloudy
# [1435] Skipped Normal: Too cloudy
# [1516] Skipped Normal: Too cloudy
# [1531] Skipped Normal: Too cloudy
# [1555] Skipped Normal: Too cloudy
# [1558] Skipped Normal: Too cloudy
# [1562] Skipped Normal: Too cloudy
# [1582] Skipped Normal: Too cloudy
# [1601] Skipped Normal: Too cloudy
# [1621] Skipped Normal: Too cloudy
# [1668] Skipped Normal: Too cloudy
# [1689] Skipped Normal: Too cloudy
# [1704] Skipped Normal: Too cloudy
# [1731] Skipped Normal: Too cloudy
# [1740] Skipped Normal: Too cloudy
# [1748] Skipped Normal: Too cloudy
# [1750] Skipped Normal: Too cloudy
# [1821] Skipped Normal: Too cloudy
# [1832] Skipped Normal: Too cloudy
# [1839] Skipped Normal: Too cloudy
# [1849] Skipped Normal: Too cloudy
# [1875] Skipped Normal: Too cloudy
# [1910] Skipped Normal: Too cloudy
# [1962] Skipped Normal: Too cloudy
# [1971] Skipped Normal: Too cloudy
# [1999] Skipped Normal: Too cloudy
# [2030] Skipped Normal: Too cloudy
# [2035] Skipped Normal: Too cloudy
# [2057] Skipped Normal: Too cloudy
# [2073] Skipped Normal: Too cloudy
# [2083] Skipped Normal: Too cloudy
# [2091] Skipped Normal: Too cloudy
# [2093] Skipped Normal: Too cloudy
# [2109] Skipped Normal: Too cloudy
# [2172] Skipped Normal: Too cloudy
# [2177] Skipped Normal: Too cloudy
# [2184] Skipped Normal: Too cloudy
# [2191] Skipped Normal: Too cloudy
# [2220] Skipped Normal: Too cloudy
# [2234] Skipped Normal: Too cloudy
# [2300] Skipped Normal: Too cloudy
# [2336] Skipped Normal: Too cloudy
# [2350] Skipped Normal: Too cloudy
# [2360] Skipped Normal: Too cloudy
# [2364] Skipped Normal: Too cloudy
# [2365] Skipped Normal: Too cloudy
# [2411] Skipped Normal: Too cloudy
# [2444] Skipped Normal: Too cloudy
# [2454] Skipped Normal: Too cloudy
# [2464] Skipped Normal: Too cloudy
# [2473] Skipped Normal: Too cloudy
# [2476] Skipped Normal: Too cloudy
# [2483] Skipped Normal: Too cloudy
# [2492] Skipped Normal: Too cloudy
# [2519] Skipped Normal: Too cloudy
# [2585] Skipped Normal: Too cloudy
# [2589] Skipped Normal: Too cloudy
# [2598] Skipped Normal: Too cloudy
# [2640] Skipped Normal: Too cloudy
# [2646] Skipped Normal: Too cloudy
# [2731] Skipped Normal: Too cloudy
# [2751] Skipped Normal: Too cloudy
# [2827] Skipped Normal: Too cloudy
# [2831] Skipped Normal: Too cloudy
# [2860] Skipped Normal: Too cloudy
# [2887] Skipped Normal: Too cloudy
# [2939] Skipped Normal: Too cloudy
# [2940] Skipped Normal: Too cloudy
# [3029] Skipped Normal: Too cloudy
# [3033] Skipped Normal: Too cloudy
# [3063] Skipped Normal: Too cloudy
# [3067] Skipped Normal: Too cloudy
# [3071] Skipped Normal: Too cloudy
# [3074] Skipped Normal: Too cloudy
# [3077] Skipped Normal: Too cloudy
# [3091] Skipped Normal: Too cloudy
# [3096] Skipped Normal: Too cloudy
# [3097] Skipped Normal: Too cloudy
# [3102] Skipped Normal: Too cloudy
# [3135] Skipped Normal: Too cloudy
# [3145] Skipped Normal: Too cloudy
# [3154] Skipped Normal: Too cloudy
# [3185] Skipped Normal: Too cloudy
# [3201] Skipped Normal: Too cloudy
# [3220] Skipped Normal: Too cloudy
# [3262] Skipped Normal: Too cloudy
# [3283] Skipped Normal: Too cloudy
# [3310] Skipped Normal: Too cloudy
# [3354] Skipped Normal: Too cloudy
# [3370] Skipped Normal: Too cloudy
# [3402] Skipped Normal: Too cloudy
# [3431] Skipped Normal: Too cloudy
# [3444] Skipped Normal: Too cloudy
# [3453] Skipped Normal: Too cloudy
# [3494] Skipped Normal: Too cloudy
# [3524] Skipped Normal: Too cloudy
# [3537] Skipped Normal: Too cloudy
# [3543] Skipped Normal: Too cloudy
# [3556] Skipped Normal: Too cloudy
# [3577] Skipped Normal: Too cloudy
# [3584] Skipped Normal: Too cloudy
# [3589] Skipped Normal: Too cloudy
# [3606] Skipped Normal: Too cloudy
# [3621] Skipped Normal: Too cloudy
# [3636] Skipped Normal: Too cloudy
# [3638] Skipped Normal: Too cloudy
# [3680] Skipped Normal: Too cloudy
# [3720] Skipped Normal: Too cloudy
# [3757] Skipped Normal: Too cloudy
# [3769] Skipped Normal: Too cloudy
# [3776] Skipped Normal: Too cloudy
# [3831] Skipped Normal: Too cloudy
# [3859] Skipped Normal: Too cloudy
# [3916] Skipped Normal: Too cloudy
# [3959] Skipped Normal: Too cloudy
# [3966] Skipped Normal: Too cloudy
# [4032] Skipped Normal: Too cloudy
# [4038] Skipped Normal: Too cloudy
# [4047] Skipped Normal: Too cloudy
# [4056] Skipped Normal: Too cloudy
# [4069] Skipped Normal: Too cloudy
# [4084] Skipped Normal: Too cloudy
# [4086] Skipped Normal: Too cloudy
# [4090] Skipped Normal: Too cloudy
# [4096] Skipped Normal: Too cloudy
# [4105] Skipped Normal: Too cloudy
# [4125] Skipped Normal: Too cloudy
# [4133] Skipped Normal: Too cloudy
# [4142] Skipped Normal: Too cloudy
# [4188] Skipped Normal: Too cloudy
# [4194] Skipped Normal: Too cloudy
# [4201] Skipped Normal: Too cloudy
# [4205] Skipped Normal: Too cloudy
# [4217] Skipped Normal: Too cloudy
# [4227] Skipped Normal: Too cloudy
# [4249] Skipped Normal: Too cloudy
# [4295] Skipped Normal: Too cloudy
# [4344] Skipped Normal: Too cloudy
# [4351] Skipped Normal: Too cloudy
# [4362] Skipped Normal: Too cloudy
# [4380] Skipped Normal: Too cloudy
# [4389] Skipped Normal: Too cloudy
# [4405] Skipped Normal: Too cloudy
# [4429] Skipped Normal: Too cloudy
# [4431] Skipped Normal: Too cloudy
# [4436] Skipped Normal: Too cloudy
# [4472] Skipped Normal: Too cloudy
# [4474] Skipped Normal: Too cloudy
# [4500] Skipped Normal: Too cloudy
# [4551] Skipped Normal: Too cloudy
# [4629] Skipped Normal: Too cloudy
# [4631] Skipped Normal: Too cloudy
# [4648] Skipped Normal: Too cloudy
# [4653] Skipped Normal: Too cloudy
# [4701] Skipped Normal: Too cloudy
# [4705] Skipped Normal: Too cloudy
# [4707] Skipped Normal: Too cloudy
# [4715] Skipped Normal: Too cloudy
# [4735] Skipped Normal: Too cloudy
# [4738] Skipped Normal: Too cloudy
# [4757] Skipped Normal: Too cloudy
# [4848] Skipped Normal: Too cloudy
# [4858] Skipped Normal: Too cloudy
# [4944] Skipped Normal: Too cloudy
# [5017] Skipped Normal: Too cloudy
# [5034] Skipped Normal: Too cloudy
# Saved: fire_5063_2024-09-12.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5071_2023-08-12.png
# [5071] Downloaded Pair (Fire: 2024-08-24 | Normal: 2023-08-12)
# Saved: fire_5072_2024-09-19.png
# Saved: fire_5077_2024-08-31.png
# Saved: normal_5079_2023-08-30.png
# [5079] Downloaded Pair (Fire: 2024-09-07 | Normal: 2023-08-30)
# Saved: normal_5086_2023-08-11.png
# [5086] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-11)
# Saved: fire_5087_2024-09-26.png
# Saved: normal_5088_2023-09-27.png
# [5088] Downloaded Pair (Fire: 2024-10-09 | Normal: 2023-09-27)
# Saved: normal_5089_2023-08-15.png
# [5089] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-15)
# [5100] Skipped Normal: Too cloudy
# Saved: fire_5102_2024-10-17.png
# [5103] Skipped Normal: Too cloudy
# Saved: fire_5106_2024-11-29.png
# [5106] Skipped Normal: Too cloudy
# Saved: normal_5107_2023-08-22.png
# [5107] Downloaded Pair (Fire: 2024-09-02 | Normal: 2023-08-22)
# Saved: fire_5110_2024-03-22.png
# Saved: normal_5111_2023-09-19.png
# [5111] Downloaded Pair (Fire: 2024-09-30 | Normal: 2023-09-19)
# Saved: fire_5114_2024-08-19.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5119] Downloaded Pair (Fire: 2024-09-13 | Normal: 2023-09-04)
# Saved: normal_5124_2023-08-30.png
# [5124] Downloaded Pair (Fire: 2024-09-12 | Normal: 2023-08-30)
# Saved: fire_5127_2024-11-09.png
# [5127] Skipped Normal: Too cloudy
# Saved: fire_5132_2024-08-23.png
# Saved: fire_5135_2024-08-20.png
# Saved: normal_5135_2023-08-07.png
# [5135] Downloaded Pair (Fire: 2024-08-20 | Normal: 2023-08-07)
# Saved: fire_5136_2024-06-09.png
# [5153] Skipped Normal: Too cloudy
# [5155] Skipped Normal: Too cloudy
# Saved: fire_5157_2024-08-14.png
# Saved: normal_5158_2023-08-16.png
# [5158] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-16)
# [5160] Skipped Normal: Too cloudy
# Saved: fire_5161_2024-12-17.png
# Saved: normal_5163_2023-08-28.png
# [5163] Downloaded Pair (Fire: 2024-09-07 | Normal: 2023-08-28)
# Saved: fire_5165_2024-09-11.png
# Saved: normal_5165_2023-08-31.png
# [5165] Downloaded Pair (Fire: 2024-09-11 | Normal: 2023-08-31)
# Saved: normal_5170_2023-08-09.png
# [5170] Downloaded Pair (Fire: 2024-08-22 | Normal: 2023-08-09)
# Saved: normal_5171_2023-09-23.png
# [5171] Downloaded Pair (Fire: 2024-10-04 | Normal: 2023-09-23)
# Saved: fire_5179_2024-08-31.png
# Saved: fire_5182_2024-09-16.png
# Saved: fire_5183_2024-09-28.png
# Saved: normal_5183_2023-09-15.png
# [5183] Downloaded Pair (Fire: 2024-09-28 | Normal: 2023-09-15)
# Saved: fire_5188_2024-08-31.png
# Saved: normal_5191_2023-08-26.png
# [5191] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-26)
# Saved: fire_5192_2024-07-23.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5196] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-23)
# Saved: fire_5198_2024-08-30.png
# Saved: fire_5200_2024-08-09.png
# Saved: fire_5201_2024-09-05.png
# Saved: fire_5205_2024-08-03.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5207] Skipped Normal: Too cloudy
# Saved: normal_5210_2023-09-02.png
# [5210] Downloaded Pair (Fire: 2024-09-11 | Normal: 2023-09-02)
# Saved: normal_5211_2023-07-14.png
# [5211] Downloaded Pair (Fire: 2024-07-27 | Normal: 2023-07-14)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5213_2023-09-09.png
# [5213] Downloaded Pair (Fire: 2024-09-21 | Normal: 2023-09-09)
# Saved: fire_5214_2024-10-04.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5215] Downloaded Pair (Fire: 2024-10-08 | Normal: 2023-09-30)
# Saved: fire_5220_2024-09-09.png
# Saved: normal_5225_2022-12-28.png
# [5225] Downloaded Pair (Fire: 2024-01-03 | Normal: 2022-12-28)
# Saved: normal_5226_2023-09-24.png
# [5226] Downloaded Pair (Fire: 2024-10-07 | Normal: 2023-09-24)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5233_2024-08-22.png
# Saved: normal_5233_2023-08-10.png
# [5233] Downloaded Pair (Fire: 2024-08-22 | Normal: 2023-08-10)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5234] Downloaded Pair (Fire: 2024-07-23 | Normal: 2023-07-10)
# Saved: normal_5235_2023-09-10.png
# [5235] Downloaded Pair (Fire: 2024-09-19 | Normal: 2023-09-10)
# [5236] Skipped Normal: Too cloudy
# Saved: normal_5238_2023-09-15.png
# [5238] Downloaded Pair (Fire: 2024-09-27 | Normal: 2023-09-15)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5239_2023-10-20.png
# [5239] Downloaded Pair (Fire: 2024-10-30 | Normal: 2023-10-20)
# Saved: normal_5240_2023-08-21.png
# [5240] Downloaded Pair (Fire: 2024-09-02 | Normal: 2023-08-21)
# Saved: normal_5241_2023-08-28.png
# [5241] Downloaded Pair (Fire: 2024-09-10 | Normal: 2023-08-28)
# [5242] Skipped Normal: Too cloudy
# Saved: normal_5246_2023-07-17.png
# [5246] Downloaded Pair (Fire: 2024-07-23 | Normal: 2023-07-17)
# Saved: normal_5248_2023-06-19.png
# [5248] Downloaded Pair (Fire: 2024-07-01 | Normal: 2023-06-19)
# [5249] Skipped Normal: Too cloudy
# Saved: fire_5250_2024-09-23.png
# Saved: normal_5253_2023-10-31.png
# [5253] Downloaded Pair (Fire: 2024-11-13 | Normal: 2023-10-31)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5254] Downloaded Pair (Fire: 2024-10-10 | Normal: 2023-09-28)
# Saved: fire_5255_2024-09-02.png
# Saved: normal_5255_2023-08-20.png
# [5255] Downloaded Pair (Fire: 2024-09-02 | Normal: 2023-08-20)
# Saved: normal_5257_2023-06-03.png
# [5257] Downloaded Pair (Fire: 2024-06-12 | Normal: 2023-06-03)
# Saved: normal_5262_2023-02-23.png
# [5262] Downloaded Pair (Fire: 2024-02-24 | Normal: 2023-02-23)
# Saved: normal_5263_2023-08-28.png
# [5263] Downloaded Pair (Fire: 2024-09-02 | Normal: 2023-08-28)
# Saved: normal_5267_2023-09-13.png
# [5267] Downloaded Pair (Fire: 2024-09-25 | Normal: 2023-09-13)
# Saved: fire_5269_2024-09-12.png
# Saved: normal_5269_2023-09-02.png
# [5269] Downloaded Pair (Fire: 2024-09-12 | Normal: 2023-09-02)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5270] Downloaded Pair (Fire: 2024-08-30 | Normal: 2023-08-17)
# Saved: fire_5271_2024-08-10.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5278] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5279] Downloaded Pair (Fire: 2024-08-30 | Normal: 2023-08-18)
# [5280] Skipped Normal: Too cloudy
# Saved: fire_5281_2024-09-20.png
# Saved: fire_5284_2024-09-30.png
# Saved: normal_5286_2023-09-22.png
# [5286] Downloaded Pair (Fire: 2024-09-20 | Normal: 2023-09-22)
# Saved: fire_5288_2024-07-28.png
# Saved: normal_5291_2023-09-15.png
# [5291] Downloaded Pair (Fire: 2024-09-25 | Normal: 2023-09-15)
# Saved: fire_5292_2024-10-30.png
# Saved: fire_5297_2024-09-19.png
# Saved: normal_5297_2023-09-10.png
# [5297] Downloaded Pair (Fire: 2024-09-19 | Normal: 2023-09-10)
# Saved: fire_5303_2024-09-05.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5304] Skipped Normal: Too cloudy
# Saved: fire_5306_2024-12-08.png
# [5306] Skipped Normal: Too cloudy
# Saved: fire_5312_2024-07-23.png
# Saved: normal_5313_2023-08-06.png
# [5313] Downloaded Pair (Fire: 2024-08-18 | Normal: 2023-08-06)
# [5314] Skipped Normal: Too cloudy
# Saved: normal_5315_2023-09-08.png
# [5315] Downloaded Pair (Fire: 2024-09-21 | Normal: 2023-09-08)
# Saved: normal_5317_2023-08-29.png
# [5317] Downloaded Pair (Fire: 2024-09-05 | Normal: 2023-08-29)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5319] Downloaded Pair (Fire: 2024-09-26 | Normal: 2023-09-13)
# Saved: normal_5322_2023-10-27.png
# [5322] Downloaded Pair (Fire: 2024-11-06 | Normal: 2023-10-27)
# Saved: fire_5323_2024-09-03.png
# Saved: normal_5323_2023-08-22.png
# [5323] Downloaded Pair (Fire: 2024-09-03 | Normal: 2023-08-22)
# Saved: fire_5324_2024-08-23.png
# Saved: normal_5325_2023-08-28.png
# [5325] Downloaded Pair (Fire: 2024-09-09 | Normal: 2023-08-28)
# Saved: normal_5328_2023-07-24.png
# [5328] Downloaded Pair (Fire: 2024-07-30 | Normal: 2023-07-24)
# Saved: normal_5330_2023-08-17.png
# [5330] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-17)
# Saved: normal_5331_2023-09-01.png
# [5331] Downloaded Pair (Fire: 2024-09-13 | Normal: 2023-09-01)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5333_2023-08-09.png
# [5333] Downloaded Pair (Fire: 2024-08-21 | Normal: 2023-08-09)
# Saved: fire_5334_2024-08-19.png
# Saved: fire_5336_2024-11-13.png
# [5336] Skipped Normal: Too cloudy
# Saved: normal_5339_2023-09-12.png
# [5339] Downloaded Pair (Fire: 2024-09-23 | Normal: 2023-09-12)
# Saved: fire_5343_2024-02-24.png
# [5343] Skipped Normal: Too cloudy
# Saved: normal_5344_2023-07-15.png
# [5344] Downloaded Pair (Fire: 2024-07-28 | Normal: 2023-07-15)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5351] Downloaded Pair (Fire: 2024-09-07 | Normal: 2023-08-25)
# Saved: normal_5354_2023-08-15.png
# [5354] Downloaded Pair (Fire: 2024-08-27 | Normal: 2023-08-15)
# Saved: fire_5359_2024-09-26.png
# [5365] Skipped Normal: Too cloudy
# Saved: fire_5369_2024-06-18.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5373_2023-08-26.png
# [5373] Downloaded Pair (Fire: 2024-09-07 | Normal: 2023-08-26)
# Saved: normal_5376_2023-08-10.png
# [5376] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-10)
# Saved: fire_5380_2024-08-29.png
# Saved: normal_5380_2023-08-16.png
# [5380] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-16)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5382_2023-06-17.png
# [5382] Downloaded Pair (Fire: 2024-06-29 | Normal: 2023-06-17)
# Saved: fire_5384_2024-08-03.png
# Saved: normal_5385_2023-10-14.png
# [5385] Downloaded Pair (Fire: 2024-10-24 | Normal: 2023-10-14)
# Saved: normal_5386_2023-08-28.png
# [5386] Downloaded Pair (Fire: 2024-09-10 | Normal: 2023-08-28)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5394_2023-09-30.png
# [5394] Downloaded Pair (Fire: 2024-10-12 | Normal: 2023-09-30)
# Saved: fire_5395_2024-08-17.png
# Saved: fire_5396_2024-11-01.png
# Saved: fire_5400_2024-08-26.png
# Saved: normal_5401_2023-08-09.png
# [5401] Downloaded Pair (Fire: 2024-08-22 | Normal: 2023-08-09)
# Saved: normal_5402_2023-06-08.png
# [5402] Downloaded Pair (Fire: 2024-06-21 | Normal: 2023-06-08)
# [5403] Skipped Normal: Too cloudy
# Saved: fire_5405_2024-10-08.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5416] Skipped Normal: Too cloudy
# Saved: fire_5420_2024-11-04.png
# [5420] Skipped Normal: Too cloudy
# Saved: fire_5421_2024-01-29.png
# Saved: normal_5421_2023-01-20.png
# [5421] Downloaded Pair (Fire: 2024-01-29 | Normal: 2023-01-20)
# Saved: fire_5423_2024-09-15.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5428_2024-02-09.png
# Saved: fire_5436_2024-12-30.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5440] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-16)
# [5448] Skipped Normal: Too cloudy
# Saved: fire_5451_2024-12-04.png
# [5452] Skipped Normal: Too cloudy
# Saved: fire_5455_2024-01-06.png
# [5455] Skipped Normal: Too cloudy
# Saved: fire_5459_2024-09-20.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5465_2024-10-08.png
# Saved: normal_5467_2023-08-12.png
# [5467] Downloaded Pair (Fire: 2024-08-25 | Normal: 2023-08-12)
# Saved: normal_5469_2023-08-18.png
# [5469] Downloaded Pair (Fire: 2024-08-31 | Normal: 2023-08-18)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5470] Downloaded Pair (Fire: 2024-10-27 | Normal: 2023-10-20)
# Saved: fire_5476_2024-10-30.png
# Saved: normal_5480_2023-08-10.png
# [5480] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-10)
# [5481] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5483] Downloaded Pair (Fire: 2024-07-26 | Normal: 2023-07-13)
# Saved: normal_5487_2023-09-04.png
# [5487] Downloaded Pair (Fire: 2024-09-17 | Normal: 2023-09-04)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5488_2023-07-04.png
# [5488] Downloaded Pair (Fire: 2024-07-16 | Normal: 2023-07-04)
# Saved: normal_5489_2023-05-14.png
# [5489] Downloaded Pair (Fire: 2024-05-21 | Normal: 2023-05-14)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5495_2023-08-10.png
# [5495] Downloaded Pair (Fire: 2024-08-22 | Normal: 2023-08-10)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5499] Downloaded Pair (Fire: 2024-09-11 | Normal: 2023-09-02)
# Saved: fire_5501_2024-07-22.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5501] Downloaded Pair (Fire: 2024-07-22 | Normal: 2023-07-09)
# Saved: normal_5504_2023-07-12.png
# [5504] Downloaded Pair (Fire: 2024-07-25 | Normal: 2023-07-12)
# [5505] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5512_2024-09-20.png
# Saved: normal_5512_2023-09-07.png
# [5512] Downloaded Pair (Fire: 2024-09-20 | Normal: 2023-09-07)
# Saved: normal_5514_2023-08-17.png
# [5514] Downloaded Pair (Fire: 2024-08-30 | Normal: 2023-08-17)
# Saved: fire_5515_2024-06-16.png
# Saved: normal_5516_2023-08-10.png
# [5516] Downloaded Pair (Fire: 2024-08-22 | Normal: 2023-08-10)
# Saved: fire_5518_2024-06-01.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5518] Downloaded Pair (Fire: 2024-06-01 | Normal: 2023-05-19)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5519_2023-08-18.png
# [5519] Downloaded Pair (Fire: 2024-08-31 | Normal: 2023-08-18)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5522_2023-08-12.png
# [5522] Downloaded Pair (Fire: 2024-08-25 | Normal: 2023-08-12)
# Saved: normal_5523_2023-08-17.png
# [5523] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-17)
# Saved: normal_5525_2023-10-08.png
# [5525] Downloaded Pair (Fire: 2024-10-15 | Normal: 2023-10-08)
# Saved: fire_5527_2024-08-10.png
# Saved: normal_5528_2023-09-30.png
# [5528] Downloaded Pair (Fire: 2024-10-10 | Normal: 2023-09-30)
# Saved: normal_5529_2023-08-16.png
# [5529] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-16)
# Saved: normal_5531_2023-08-14.png
# [5531] Downloaded Pair (Fire: 2024-08-27 | Normal: 2023-08-14)
# Saved: fire_5534_2024-10-10.png
# Saved: fire_5535_2024-10-05.png
# Saved: normal_5535_2023-09-22.png
# [5535] Downloaded Pair (Fire: 2024-10-05 | Normal: 2023-09-22)
# Saved: normal_5538_2023-06-30.png
# [5538] Downloaded Pair (Fire: 2024-07-13 | Normal: 2023-06-30)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5541] Downloaded Pair (Fire: 2024-08-27 | Normal: 2023-08-15)
# Saved: fire_5543_2024-10-05.png
# Saved: fire_5546_2024-09-22.png
# Saved: normal_5547_2023-05-07.png
# [5547] Downloaded Pair (Fire: 2024-05-20 | Normal: 2023-05-07)
# Saved: normal_5549_2023-08-10.png
# [5549] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-10)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5554] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5560_2024-09-11.png
# Saved: normal_5560_2023-08-30.png
# [5560] Downloaded Pair (Fire: 2024-09-11 | Normal: 2023-08-30)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5561] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-17)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5566_2024-08-16.png
# Saved: normal_5568_2023-08-15.png
# [5568] Downloaded Pair (Fire: 2024-08-27 | Normal: 2023-08-15)
# Saved: fire_5570_2024-09-12.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5580] Downloaded Pair (Fire: 2024-09-13 | Normal: 2023-08-31)
# Saved: fire_5582_2024-09-02.png
# Saved: fire_5587_2024-09-09.png
# Saved: normal_5596_2023-08-24.png
# [5596] Downloaded Pair (Fire: 2024-09-06 | Normal: 2023-08-24)
# Saved: fire_5597_2024-06-28.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5602] Downloaded Pair (Fire: 2024-08-02 | Normal: 2023-07-21)
# Saved: fire_5607_2024-10-24.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5608] Downloaded Pair (Fire: 2024-09-09 | Normal: 2023-09-09)
# Saved: fire_5610_2024-09-08.png
# Saved: normal_5610_2023-08-29.png
# [5610] Downloaded Pair (Fire: 2024-09-08 | Normal: 2023-08-29)
# Saved: normal_5611_2023-08-14.png
# [5611] Downloaded Pair (Fire: 2024-08-27 | Normal: 2023-08-14)
# Saved: fire_5613_2024-09-12.png
# Saved: normal_5614_2023-08-26.png
# [5614] Downloaded Pair (Fire: 2024-09-07 | Normal: 2023-08-26)
# Saved: normal_5615_2023-09-25.png
# [5615] Downloaded Pair (Fire: 2024-10-07 | Normal: 2023-09-25)
# Saved: fire_5618_2024-09-16.png
# Saved: normal_5620_2023-08-21.png
# [5620] Downloaded Pair (Fire: 2024-09-03 | Normal: 2023-08-21)
# Saved: normal_5622_2023-08-02.png
# [5622] Downloaded Pair (Fire: 2024-08-14 | Normal: 2023-08-02)
# Saved: normal_5623_2023-06-09.png
# [5623] Downloaded Pair (Fire: 2024-06-19 | Normal: 2023-06-09)
# Saved: fire_5624_2024-10-02.png
# Saved: fire_5626_2024-11-01.png
# Saved: normal_5626_2023-10-25.png
# [5626] Downloaded Pair (Fire: 2024-11-01 | Normal: 2023-10-25)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5628_2023-07-26.png
# [5628] Downloaded Pair (Fire: 2024-08-07 | Normal: 2023-07-26)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5629] Downloaded Pair (Fire: 2024-06-06 | Normal: 2023-05-25)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5639_2023-11-25.png
# [5639] Downloaded Pair (Fire: 2024-12-02 | Normal: 2023-11-25)
# Saved: fire_5641_2024-02-17.png
# [5641] Skipped Normal: Too cloudy
# Saved: fire_5644_2024-09-14.png
# Saved: normal_5645_2023-09-19.png
# [5645] Downloaded Pair (Fire: 2024-10-01 | Normal: 2023-09-19)
# Saved: fire_5646_2024-10-10.png
# [5646] Skipped Normal: Too cloudy
# Saved: fire_5647_2024-08-29.png
# Saved: fire_5648_2024-09-03.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5650_2024-09-20.png
# Saved: normal_5650_2023-09-08.png
# [5650] Downloaded Pair (Fire: 2024-09-20 | Normal: 2023-09-08)
# Saved: normal_5651_2023-01-02.png
# [5651] Downloaded Pair (Fire: 2024-01-08 | Normal: 2023-01-02)
# Saved: normal_5666_2023-11-12.png
# [5666] Downloaded Pair (Fire: 2024-11-24 | Normal: 2023-11-12)
# Saved: normal_5688_2023-05-31.png
# [5688] Downloaded Pair (Fire: 2024-06-13 | Normal: 2023-05-31)
# Saved: fire_5691_2024-09-21.png
# Saved: fire_5695_2024-10-09.png
# Saved: normal_5695_2023-09-26.png
# [5695] Downloaded Pair (Fire: 2024-10-09 | Normal: 2023-09-26)
# Saved: fire_5696_2024-11-14.png
# [5698] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5701_2023-09-10.png
# [5701] Downloaded Pair (Fire: 2024-09-07 | Normal: 2023-09-10)
# Saved: normal_5702_2023-08-01.png
# [5702] Downloaded Pair (Fire: 2024-08-14 | Normal: 2023-08-01)
# Saved: fire_5709_2024-10-22.png
# Saved: normal_5709_2023-10-12.png
# [5709] Downloaded Pair (Fire: 2024-10-22 | Normal: 2023-10-12)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5713] Skipped Normal: Too cloudy
# Saved: normal_5714_2023-08-23.png
# [5714] Downloaded Pair (Fire: 2024-09-01 | Normal: 2023-08-23)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5725] Downloaded Pair (Fire: 2024-11-13 | Normal: 2023-10-31)
# Saved: fire_5726_2024-10-29.png
# Saved: fire_5727_2024-08-13.png
# Saved: normal_5727_2023-08-14.png
# [5727] Downloaded Pair (Fire: 2024-08-13 | Normal: 2023-08-14)
# Saved: fire_5729_2024-07-20.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5731] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5736] Downloaded Pair (Fire: 2024-09-10 | Normal: 2023-08-28)
# Saved: fire_5743_2024-10-24.png
# Saved: normal_5743_2023-10-11.png
# [5743] Downloaded Pair (Fire: 2024-10-24 | Normal: 2023-10-11)
# Saved: normal_5744_2023-07-06.png
# [5744] Downloaded Pair (Fire: 2024-07-19 | Normal: 2023-07-06)
# Saved: fire_5748_2024-08-14.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5753] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-16)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5758] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5760] Downloaded Pair (Fire: 2024-04-24 | Normal: 2023-04-11)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5761] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-10)
# [5762] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5767] Skipped Normal: Too cloudy
# Saved: normal_5772_2023-08-16.png
# [5772] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-16)
# Saved: fire_5781_2024-08-19.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1/projects/vae-wgan/thumbnails/80c40087e563a322fab8d8cea125757b-88acef2929df77952a7c5f6b92df6a42:getPixels (Caused by SSLError(SSLWantReadError(2, 'The operation did not complete (read) (_ssl.c:2588)')))
# Saved: fire_5785_2024-12-01.png
# [5785] Skipped Normal: Too cloudy
# [5788] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5791_2023-09-25.png
# [5791] Downloaded Pair (Fire: 2024-10-06 | Normal: 2023-09-25)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5792] Skipped Normal: Too cloudy
# Saved: normal_5794_2023-07-21.png
# [5794] Downloaded Pair (Fire: 2024-08-03 | Normal: 2023-07-21)
# Saved: normal_5796_2023-09-03.png
# [5796] Downloaded Pair (Fire: 2024-09-15 | Normal: 2023-09-03)
# Saved: fire_5797_2024-09-01.png
# Saved: normal_5799_2023-06-07.png
# [5799] Downloaded Pair (Fire: 2024-06-20 | Normal: 2023-06-07)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5802] Skipped Normal: Too cloudy
# Saved: fire_5806_2024-09-07.png
# Saved: fire_5807_2024-09-06.png
# [5808] Skipped Normal: Too cloudy
# Saved: fire_5810_2024-09-11.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5811] Downloaded Pair (Fire: 2024-11-05 | Normal: 2023-10-26)
# [5813] Skipped Normal: Too cloudy
# Saved: normal_5817_2023-09-18.png
# [5817] Downloaded Pair (Fire: 2024-09-27 | Normal: 2023-09-18)
# Saved: fire_5821_2024-08-23.png
# Saved: fire_5822_2024-12-20.png
# [5822] Skipped Normal: Too cloudy
# Saved: fire_5823_2024-08-27.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5826] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5828] Downloaded Pair (Fire: 2024-10-18 | Normal: 2023-10-10)
# Saved: normal_5830_2023-09-02.png
# [5830] Downloaded Pair (Fire: 2024-09-10 | Normal: 2023-09-02)
# Saved: normal_5832_2023-08-10.png
# [5832] Downloaded Pair (Fire: 2024-08-22 | Normal: 2023-08-10)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5837_2023-09-12.png
# [5837] Downloaded Pair (Fire: 2024-09-12 | Normal: 2023-09-12)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5838_2023-08-16.png
# [5838] Downloaded Pair (Fire: 2024-08-27 | Normal: 2023-08-16)
# Saved: normal_5839_2023-08-11.png
# [5839] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-11)
# Saved: fire_5842_2024-09-19.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5845] Downloaded Pair (Fire: 2024-08-20 | Normal: 2023-08-08)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5847] Downloaded Pair (Fire: 2024-10-10 | Normal: 2023-10-03)
# Saved: normal_5848_2023-08-18.png
# [5848] Downloaded Pair (Fire: 2024-08-30 | Normal: 2023-08-18)
# Saved: normal_5850_2023-08-10.png
# [5850] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-10)
# Saved: normal_5851_2023-07-14.png
# [5851] Downloaded Pair (Fire: 2024-07-27 | Normal: 2023-07-14)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5853] Downloaded Pair (Fire: 2024-07-28 | Normal: 2023-07-15)
# Saved: fire_5856_2024-12-26.png
# [5856] Skipped Normal: Too cloudy
# [5859] Skipped Normal: Too cloudy
# Saved: normal_5860_2023-07-23.png
# [5860] Downloaded Pair (Fire: 2024-08-05 | Normal: 2023-07-23)
# Saved: fire_5862_2024-09-10.png
# Saved: normal_5863_2023-08-13.png
# [5863] Downloaded Pair (Fire: 2024-08-26 | Normal: 2023-08-13)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5868_2023-08-04.png
# [5868] Downloaded Pair (Fire: 2024-08-17 | Normal: 2023-08-04)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5870] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-16)
# Saved: fire_5877_2024-08-31.png
# Saved: normal_5878_2023-08-10.png
# [5878] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-10)
# Saved: fire_5883_2024-09-13.png
# [5883] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5884_2023-06-10.png
# [5884] Downloaded Pair (Fire: 2024-06-21 | Normal: 2023-06-10)
# Saved: normal_5897_2023-07-24.png
# [5897] Downloaded Pair (Fire: 2024-08-06 | Normal: 2023-07-24)
# Saved: fire_5898_2024-03-22.png
# [5899] Skipped Normal: Too cloudy
# Saved: fire_5903_2024-10-04.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_5904_2023-08-18.png
# [5904] Downloaded Pair (Fire: 2024-08-31 | Normal: 2023-08-18)
# Saved: fire_5909_2024-10-01.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5910] Downloaded Pair (Fire: 2024-08-22 | Normal: 2023-08-09)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5912] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5915] Downloaded Pair (Fire: 2024-09-06 | Normal: 2023-08-24)
# Saved: normal_5920_2023-09-13.png
# [5920] Downloaded Pair (Fire: 2024-09-26 | Normal: 2023-09-13)
# Saved: fire_5922_2024-01-18.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5926] Downloaded Pair (Fire: 2024-10-06 | Normal: 2023-09-23)
# Saved: normal_5930_2023-08-16.png
# [5930] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-16)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5935] Downloaded Pair (Fire: 2024-03-14 | Normal: 2023-03-08)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5941] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5942] Downloaded Pair (Fire: 2024-09-06 | Normal: 2023-08-24)
# Saved: fire_5944_2024-08-15.png
# Saved: fire_5952_2024-10-16.png
# [5952] Skipped Normal: Too cloudy
# Saved: fire_5953_2024-09-12.png
# Saved: normal_5954_2023-11-22.png
# [5954] Downloaded Pair (Fire: 2024-12-05 | Normal: 2023-11-22)
# Saved: fire_5958_2024-09-03.png
# Saved: fire_5959_2024-08-02.png
# [5960] Skipped Normal: Too cloudy
# Saved: fire_5970_2024-09-10.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_5977_2024-08-07.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5980] Downloaded Pair (Fire: 2024-07-28 | Normal: 2023-07-17)
# Saved: fire_5981_2024-09-13.png
# [5985] Skipped Normal: Too cloudy
# [5986] Skipped Normal: Too cloudy
# Saved: fire_5988_2024-11-07.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [5990] Downloaded Pair (Fire: 2024-08-14 | Normal: 2023-08-02)
# Saved: fire_5991_2024-08-06.png
# Saved: normal_5991_2023-07-24.png
# [5991] Downloaded Pair (Fire: 2024-08-06 | Normal: 2023-07-24)
# Saved: normal_5996_2023-07-19.png
# [5996] Downloaded Pair (Fire: 2024-07-28 | Normal: 2023-07-19)
# Saved: fire_5999_2024-11-09.png
# Saved: normal_5999_2023-11-13.png
# [5999] Downloaded Pair (Fire: 2024-11-09 | Normal: 2023-11-13)
# [6001] Skipped Normal: Too cloudy
# [6002] Skipped Normal: Too cloudy
# Saved: normal_6005_2023-05-24.png
# [6005] Downloaded Pair (Fire: 2024-06-06 | Normal: 2023-05-24)
# Saved: fire_6007_2024-09-04.png
# Saved: normal_6009_2023-09-02.png
# [6009] Downloaded Pair (Fire: 2024-09-15 | Normal: 2023-09-02)
# Saved: fire_6010_2024-09-14.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_6015_2023-11-10.png
# [6015] Downloaded Pair (Fire: 2024-11-21 | Normal: 2023-11-10)
# Saved: normal_6018_2023-08-16.png
# [6018] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-16)
# Saved: normal_6026_2023-08-16.png
# [6026] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-16)
# [6029] Skipped Normal: Too cloudy
# [6033] Skipped Normal: Too cloudy
# Saved: normal_6035_2023-10-27.png
# [6035] Downloaded Pair (Fire: 2024-11-09 | Normal: 2023-10-27)
# Saved: fire_6039_2024-09-14.png
# Saved: normal_6039_2023-09-02.png
# [6039] Downloaded Pair (Fire: 2024-09-14 | Normal: 2023-09-02)
# Saved: normal_6043_2023-10-03.png
# [6043] Downloaded Pair (Fire: 2024-10-14 | Normal: 2023-10-03)
# Saved: fire_6044_2024-07-16.png
# Saved: normal_6044_2023-07-04.png
# [6044] Downloaded Pair (Fire: 2024-07-16 | Normal: 2023-07-04)
# [6046] Skipped Normal: Too cloudy
# Saved: fire_6049_2024-08-26.png
# Saved: normal_6049_2023-08-15.png
# [6049] Downloaded Pair (Fire: 2024-08-26 | Normal: 2023-08-15)
# Saved: normal_6052_2023-09-23.png
# [6052] Downloaded Pair (Fire: 2024-09-28 | Normal: 2023-09-23)
# Saved: normal_6054_2023-07-17.png
# [6054] Downloaded Pair (Fire: 2024-07-30 | Normal: 2023-07-17)
# Saved: normal_6055_2023-08-29.png
# [6055] Downloaded Pair (Fire: 2024-09-05 | Normal: 2023-08-29)
# [6056] Skipped Normal: Too cloudy
# Saved: normal_6060_2023-09-04.png
# [6060] Downloaded Pair (Fire: 2024-09-16 | Normal: 2023-09-04)
# Saved: fire_6073_2024-09-04.png
# Saved: normal_6082_2023-10-21.png
# [6082] Downloaded Pair (Fire: 2024-10-30 | Normal: 2023-10-21)
# Saved: fire_6084_2024-11-08.png
# Saved: fire_6090_2024-09-20.png
# Saved: normal_6090_2023-09-10.png
# [6090] Downloaded Pair (Fire: 2024-09-20 | Normal: 2023-09-10)
# Saved: fire_6094_2024-09-27.png
# Saved: fire_6096_2024-08-18.png
# Saved: fire_6101_2024-08-05.png
# Saved: normal_6101_2023-07-23.png
# [6101] Downloaded Pair (Fire: 2024-08-05 | Normal: 2023-07-23)
# Saved: normal_6103_2023-09-10.png
# [6103] Downloaded Pair (Fire: 2024-09-23 | Normal: 2023-09-10)
# Saved: normal_6104_2023-10-19.png
# [6104] Downloaded Pair (Fire: 2024-10-27 | Normal: 2023-10-19)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_6110_2023-09-02.png
# [6110] Downloaded Pair (Fire: 2024-09-14 | Normal: 2023-09-02)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6111] Downloaded Pair (Fire: 2024-09-14 | Normal: 2023-09-04)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_6114_2023-07-21.png
# [6114] Downloaded Pair (Fire: 2024-08-01 | Normal: 2023-07-21)
# Saved: normal_6116_2023-10-04.png
# [6116] Downloaded Pair (Fire: 2024-10-17 | Normal: 2023-10-04)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_6117_2023-09-30.png
# [6117] Downloaded Pair (Fire: 2024-10-11 | Normal: 2023-09-30)
# Saved: fire_6119_2024-08-21.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6123] Skipped Normal: Too cloudy
# Saved: normal_6127_2023-08-12.png
# [6127] Downloaded Pair (Fire: 2024-08-25 | Normal: 2023-08-12)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6128] Downloaded Pair (Fire: 2024-08-06 | Normal: 2023-07-24)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out.
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6129] Downloaded Pair (Fire: 2024-09-22 | Normal: 2023-09-09)
# Saved: normal_6132_2023-11-15.png
# [6132] Downloaded Pair (Fire: 2024-11-27 | Normal: 2023-11-15)
# Saved: normal_6133_2023-07-24.png
# [6133] Downloaded Pair (Fire: 2024-08-06 | Normal: 2023-07-24)
# Saved: normal_6134_2023-09-08.png
# [6134] Downloaded Pair (Fire: 2024-09-16 | Normal: 2023-09-08)
# [6137] Skipped Normal: Too cloudy
# Saved: fire_6145_2024-07-14.png
# Saved: normal_6147_2023-09-02.png
# [6147] Downloaded Pair (Fire: 2024-09-09 | Normal: 2023-09-02)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6158] Downloaded Pair (Fire: 2024-07-03 | Normal: 2023-06-20)
# Saved: normal_6162_2023-09-01.png
# [6162] Downloaded Pair (Fire: 2024-09-12 | Normal: 2023-09-01)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6167] Skipped Normal: Too cloudy
# Saved: fire_6168_2024-09-15.png
# [6169] Skipped Normal: Too cloudy
# Saved: normal_6170_2023-08-17.png
# [6170] Downloaded Pair (Fire: 2024-08-30 | Normal: 2023-08-17)
# Saved: fire_6173_2024-01-13.png
# Saved: fire_6174_2024-09-11.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: fire_6177_2024-08-24.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_6179_2023-06-10.png
# [6179] Downloaded Pair (Fire: 2024-06-22 | Normal: 2023-06-10)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6183] Downloaded Pair (Fire: 2024-11-23 | Normal: 2023-11-10)
# [6185] Skipped Normal: Too cloudy
# Saved: fire_6187_2024-09-09.png
# Saved: normal_6187_2023-08-28.png
# [6187] Downloaded Pair (Fire: 2024-09-09 | Normal: 2023-08-28)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [6188] Downloaded Pair (Fire: 2024-07-10 | Normal: 2023-06-27)
# [6191] Skipped Normal: Too cloudy
# Saved: fire_6194_2024-08-07.png
# Saved: fire_6197_2024-10-25.png
# Saved: fire_6200_2024-08-24.png
# Saved: fire_6216_2024-06-18.png
# Saved: fire_6218_2024-08-29.png
# Saved: fire_6219_2024-08-02.png
# Saved: normal_6219_2023-07-20.png
# [6219] Downloaded Pair (Fire: 2024-08-02 | Normal: 2023-07-20)
# Saved: fire_6221_2024-08-05.png
# Saved: normal_6221_2023-07-23.png
# [6221] Downloaded Pair (Fire: 2024-08-05 | Normal: 2023-07-23)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1/projects/vae-wgan/thumbnails/7f7395df6aa2928815da332404180911-9aebde621b23c7ff904933835b596572:getPixels (Caused by SSLError(SSLWantReadError(2, 'The operation did not complete (read) (_ssl.c:2588)')))
# [6230] Skipped Normal: Too cloudy
# [6233] Skipped Normal: Too cloudy
# Saved: normal_6244_2023-08-12.png
# [6244] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-12)
# Saved: normal_6246_2023-09-19.png
# ...
# Saved: normal_11966_2023-10-25.png
# [11966] Downloaded Pair (Fire: 2024-11-02 | Normal: 2023-10-25)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_11967_2023-09-26.png
# [11967] Downloaded Pair (Fire: 2024-10-06 | Normal: 2023-09-26)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_11968_2023-11-10.png
# [11968] Downloaded Pair (Fire: 2024-11-23 | Normal: 2023-11-10)
# Saved: fire_11969_2024-09-04.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [11969] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-24)
# Saved: fire_11970_2024-07-25.png
# Saved: normal_11970_2023-07-12.png
# [11970] Downloaded Pair (Fire: 2024-07-25 | Normal: 2023-07-12)
# Saved: fire_11971_2024-09-10.png
# Saved: normal_11971_2023-09-01.png
# [11971] Downloaded Pair (Fire: 2024-09-10 | Normal: 2023-09-01)
# Saved: fire_11972_2024-05-26.png
# Saved: normal_11972_2023-05-13.png
# [11972] Downloaded Pair (Fire: 2024-05-26 | Normal: 2023-05-13)
# Saved: fire_11973_2024-10-26.png
# Saved: normal_11973_2023-10-15.png
# [11973] Downloaded Pair (Fire: 2024-10-26 | Normal: 2023-10-15)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_11974_2023-10-16.png
# [11974] Downloaded Pair (Fire: 2024-10-27 | Normal: 2023-10-16)
# Saved: fire_11975_2024-10-06.png
# Saved: normal_11975_2023-09-24.png
# [11975] Downloaded Pair (Fire: 2024-10-06 | Normal: 2023-09-24)
# Saved: fire_11976_2024-09-13.png
# Saved: normal_11976_2023-09-03.png
# [11976] Downloaded Pair (Fire: 2024-09-13 | Normal: 2023-09-03)
# Saved: fire_11977_2024-06-19.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [11977] Downloaded Pair (Fire: 2024-06-19 | Normal: 2023-06-06)
# Saved: fire_11978_2024-09-24.png
# Saved: normal_11978_2023-09-13.png
# [11978] Downloaded Pair (Fire: 2024-09-24 | Normal: 2023-09-13)
# Saved: fire_11979_2024-08-03.png
# Saved: normal_11979_2023-07-21.png
# [11979] Downloaded Pair (Fire: 2024-08-03 | Normal: 2023-07-21)
# Saved: fire_11980_2024-11-28.png
# Saved: normal_11980_2023-11-17.png
# [11980] Downloaded Pair (Fire: 2024-11-28 | Normal: 2023-11-17)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_11981_2023-07-18.png
# [11981] Downloaded Pair (Fire: 2024-07-30 | Normal: 2023-07-18)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_11982_2023-09-13.png
# [11982] Downloaded Pair (Fire: 2024-09-26 | Normal: 2023-09-13)
# Saved: fire_11983_2024-08-30.png
# Saved: normal_11983_2023-08-17.png
# [11983] Downloaded Pair (Fire: 2024-08-30 | Normal: 2023-08-17)
# Saved: fire_11984_2024-09-20.png
# Saved: normal_11984_2023-09-10.png
# [11984] Downloaded Pair (Fire: 2024-09-20 | Normal: 2023-09-10)
# Saved: fire_11985_2024-03-14.png
# Saved: normal_11985_2023-03-19.png
# [11985] Downloaded Pair (Fire: 2024-03-14 | Normal: 2023-03-19)
# Saved: fire_11986_2024-08-23.png
# Saved: normal_11986_2023-08-12.png
# [11986] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-12)
# Saved: fire_11987_2024-08-23.png
# Saved: normal_11987_2023-08-10.png
# [11987] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-10)
# Saved: fire_11988_2024-10-09.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [11988] Downloaded Pair (Fire: 2024-10-09 | Normal: 2023-09-26)
# Saved: fire_11989_2024-12-10.png
# Saved: normal_11989_2023-12-09.png
# [11989] Downloaded Pair (Fire: 2024-12-10 | Normal: 2023-12-09)
# Saved: fire_11990_2024-08-31.png
# Saved: normal_11990_2023-08-18.png
# [11990] Downloaded Pair (Fire: 2024-08-31 | Normal: 2023-08-18)
# Saved: fire_11991_2024-10-16.png
# Saved: normal_11991_2023-10-03.png
# [11991] Downloaded Pair (Fire: 2024-10-16 | Normal: 2023-10-03)
# Saved: fire_11992_2024-11-20.png
# Saved: normal_11992_2023-11-08.png
# [11992] Downloaded Pair (Fire: 2024-11-20 | Normal: 2023-11-08)
# Saved: fire_11993_2024-07-25.png
# Saved: normal_11993_2023-07-12.png
# [11993] Downloaded Pair (Fire: 2024-07-25 | Normal: 2023-07-12)
# Saved: fire_11994_2024-08-01.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [11994] Downloaded Pair (Fire: 2024-08-01 | Normal: 2023-07-19)
# Saved: fire_11995_2024-08-12.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [11995] Downloaded Pair (Fire: 2024-08-12 | Normal: 2023-07-31)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [11996] Skipped Normal: Too cloudy
# Saved: fire_11997_2024-09-04.png
# Saved: normal_11997_2023-08-22.png
# [11997] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-22)
# Saved: fire_11998_2024-10-16.png
# Saved: normal_11998_2023-10-08.png
# [11998] Downloaded Pair (Fire: 2024-10-16 | Normal: 2023-10-08)
# Saved: fire_11999_2024-08-03.png
# Saved: normal_11999_2023-07-21.png
# [11999] Downloaded Pair (Fire: 2024-08-03 | Normal: 2023-07-21)
# Saved: fire_12000_2024-08-30.png
# Saved: normal_12000_2023-08-22.png
# [12000] Downloaded Pair (Fire: 2024-08-30 | Normal: 2023-08-22)
# Saved: fire_12001_2024-08-04.png
# Saved: normal_12001_2023-07-22.png
# [12001] Downloaded Pair (Fire: 2024-08-04 | Normal: 2023-07-22)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_12002_2023-08-22.png
# [12002] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-22)
# Saved: fire_12003_2024-10-29.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [12003] Downloaded Pair (Fire: 2024-10-29 | Normal: 2023-10-16)
# Saved: fire_12004_2024-08-14.png
# Saved: normal_12004_2023-08-02.png
# [12004] Downloaded Pair (Fire: 2024-08-14 | Normal: 2023-08-02)
# Saved: fire_12005_2024-09-12.png
# Saved: normal_12005_2023-09-02.png
# [12005] Downloaded Pair (Fire: 2024-09-12 | Normal: 2023-09-02)
# Saved: fire_12006_2024-09-16.png
# Saved: normal_12006_2023-09-09.png
# [12006] Downloaded Pair (Fire: 2024-09-16 | Normal: 2023-09-09)
# Saved: fire_12007_2024-09-10.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [12007] Downloaded Pair (Fire: 2024-09-10 | Normal: 2023-08-29)
# Saved: fire_12008_2024-03-22.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Max retries exceeded with url: /v1/projects/vae-wgan/thumbnails/7f4d5fd6e8bd366eb9eb445687a57977-9c206a1f3882d942da88471db614364c:getPixels (Caused by SSLError(SSLWantReadError(2, 'The operation did not complete (read) (_ssl.c:2588)')))
# [12008] Downloaded Pair (Fire: 2024-03-22 | Normal: 2023-03-14)
# Saved: fire_12009_2024-09-09.png
# Saved: normal_12009_2023-08-29.png
# [12009] Downloaded Pair (Fire: 2024-09-09 | Normal: 2023-08-29)
# Saved: fire_12010_2024-08-06.png
# Saved: normal_12010_2023-07-24.png
# [12010] Downloaded Pair (Fire: 2024-08-06 | Normal: 2023-07-24)
# Saved: fire_12011_2024-08-27.png
# Saved: normal_12011_2023-08-15.png
# [12011] Downloaded Pair (Fire: 2024-08-27 | Normal: 2023-08-15)
# Saved: fire_12012_2024-08-09.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [12012] Downloaded Pair (Fire: 2024-08-09 | Normal: 2023-07-27)
# Saved: fire_12013_2024-08-15.png
# Saved: normal_12013_2023-08-04.png
# [12013] Downloaded Pair (Fire: 2024-08-15 | Normal: 2023-08-04)
# Saved: fire_12014_2024-10-02.png
# Saved: normal_12014_2023-09-22.png
# [12014] Downloaded Pair (Fire: 2024-10-02 | Normal: 2023-09-22)
# Saved: fire_12015_2024-09-03.png
# Saved: normal_12015_2023-08-21.png
# [12015] Downloaded Pair (Fire: 2024-09-03 | Normal: 2023-08-21)
# Saved: fire_12016_2024-09-07.png
# Saved: normal_12016_2023-08-28.png
# [12016] Downloaded Pair (Fire: 2024-09-07 | Normal: 2023-08-28)
# Saved: fire_12017_2024-09-28.png
# Saved: normal_12017_2023-09-15.png
# [12017] Downloaded Pair (Fire: 2024-09-28 | Normal: 2023-09-15)
# Saved: fire_12018_2024-07-27.png
# Saved: normal_12018_2023-07-14.png
# [12018] Downloaded Pair (Fire: 2024-07-27 | Normal: 2023-07-14)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_12019_2023-11-25.png
# [12019] Downloaded Pair (Fire: 2024-12-03 | Normal: 2023-11-25)
# Saved: fire_12020_2024-06-12.png
# Saved: normal_12020_2023-06-01.png
# [12020] Downloaded Pair (Fire: 2024-06-12 | Normal: 2023-06-01)
# Saved: fire_12021_2024-11-29.png
# [12021] Skipped Normal: Too cloudy
# Saved: fire_12022_2024-07-30.png
# Saved: normal_12022_2023-07-17.png
# [12022] Downloaded Pair (Fire: 2024-07-30 | Normal: 2023-07-17)
# Saved: fire_12023_2024-08-26.png
# Saved: normal_12023_2023-08-15.png
# [12023] Downloaded Pair (Fire: 2024-08-26 | Normal: 2023-08-15)
# Saved: fire_12024_2024-09-23.png
# Saved: normal_12024_2023-09-10.png
# [12024] Downloaded Pair (Fire: 2024-09-23 | Normal: 2023-09-10)
# Saved: fire_12025_2024-09-10.png
# Saved: normal_12025_2023-08-29.png
# [12025] Downloaded Pair (Fire: 2024-09-10 | Normal: 2023-08-29)
# Saved: fire_12026_2024-10-07.png
# Saved: normal_12026_2023-09-24.png
# [12026] Downloaded Pair (Fire: 2024-10-07 | Normal: 2023-09-24)
# Saved: fire_12027_2024-09-03.png
# Saved: normal_12027_2023-08-21.png
# [12027] Downloaded Pair (Fire: 2024-09-03 | Normal: 2023-08-21)
# Saved: fire_12028_2024-08-06.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [12028] Downloaded Pair (Fire: 2024-08-06 | Normal: 2023-07-24)
# Saved: fire_12029_2024-08-11.png
# Saved: normal_12029_2023-07-29.png
# [12029] Downloaded Pair (Fire: 2024-08-11 | Normal: 2023-07-29)
# Saved: fire_12030_2024-08-24.png
# Saved: normal_12030_2023-08-11.png
# [12030] Downloaded Pair (Fire: 2024-08-24 | Normal: 2023-08-11)
# Saved: fire_12031_2024-09-21.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [12031] Downloaded Pair (Fire: 2024-09-21 | Normal: 2023-09-11)
# Saved: fire_12032_2024-07-30.png
# Saved: normal_12032_2023-07-17.png
# [12032] Downloaded Pair (Fire: 2024-07-30 | Normal: 2023-07-17)
# Saved: fire_12033_2024-09-01.png
# Saved: normal_12033_2023-08-19.png
# [12033] Downloaded Pair (Fire: 2024-09-01 | Normal: 2023-08-19)
# Saved: fire_12034_2024-10-13.png
# Saved: normal_12034_2023-09-30.png
# [12034] Downloaded Pair (Fire: 2024-10-13 | Normal: 2023-09-30)
# Saved: fire_12035_2024-09-01.png
# Saved: normal_12035_2023-08-19.png
# [12035] Downloaded Pair (Fire: 2024-09-01 | Normal: 2023-08-19)
# Saved: fire_12036_2024-09-04.png
# Saved: normal_12036_2023-08-22.png
# [12036] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-22)
# Saved: fire_12037_2024-09-01.png
# Saved: normal_12037_2023-08-19.png
# [12037] Downloaded Pair (Fire: 2024-09-01 | Normal: 2023-08-19)
# Saved: fire_12038_2024-09-01.png
# Saved: normal_12038_2023-08-19.png
# [12038] Downloaded Pair (Fire: 2024-09-01 | Normal: 2023-08-19)
# Saved: fire_12039_2024-09-04.png
# Saved: normal_12039_2023-08-22.png
# [12039] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-22)
# Saved: fire_12040_2024-09-02.png
# Saved: normal_12040_2023-08-21.png
# [12040] Downloaded Pair (Fire: 2024-09-02 | Normal: 2023-08-21)
# Saved: fire_12041_2024-09-14.png
# Saved: normal_12041_2023-09-02.png
# [12041] Downloaded Pair (Fire: 2024-09-14 | Normal: 2023-09-02)
# Saved: fire_12042_2024-09-08.png
# Saved: normal_12042_2023-08-29.png
# [12042] Downloaded Pair (Fire: 2024-09-08 | Normal: 2023-08-29)
# Saved: fire_12043_2024-10-13.png
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# [12043] Downloaded Pair (Fire: 2024-10-13 | Normal: 2023-10-01)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_12044_2023-08-01.png
# [12044] Downloaded Pair (Fire: 2024-08-14 | Normal: 2023-08-01)
# Saved: fire_12045_2024-09-11.png
# Saved: normal_12045_2023-08-30.png
# [12045] Downloaded Pair (Fire: 2024-09-11 | Normal: 2023-08-30)
# Saved: fire_12046_2024-09-09.png
# Saved: normal_12046_2023-08-28.png
# [12046] Downloaded Pair (Fire: 2024-09-09 | Normal: 2023-08-28)
# Saved: fire_12047_2024-09-04.png
# Saved: normal_12047_2023-08-23.png
# [12047] Downloaded Pair (Fire: 2024-09-04 | Normal: 2023-08-23)
# Saved: fire_12048_2024-08-04.png
# Saved: normal_12048_2023-07-22.png
# [12048] Downloaded Pair (Fire: 2024-08-04 | Normal: 2023-07-22)
# Saved: fire_12049_2024-08-21.png
# Saved: normal_12049_2023-08-08.png
# [12049] Downloaded Pair (Fire: 2024-08-21 | Normal: 2023-08-08)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_12050_2023-08-13.png
# [12050] Downloaded Pair (Fire: 2024-08-26 | Normal: 2023-08-13)
# Saved: fire_12051_2024-01-18.png
# [12051] Skipped Normal: Too cloudy
# Saved: fire_12052_2024-09-03.png
# Saved: normal_12052_2023-08-21.png
# [12052] Downloaded Pair (Fire: 2024-09-03 | Normal: 2023-08-21)
# Saved: fire_12053_2024-08-23.png
# Saved: normal_12053_2023-08-11.png
# [12053] Downloaded Pair (Fire: 2024-08-23 | Normal: 2023-08-11)
# Saved: fire_12054_2024-08-29.png
# Saved: normal_12054_2023-08-16.png
# [12054] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-16)
# Saved: fire_12055_2024-10-22.png
# Saved: normal_12055_2023-10-10.png
# [12055] Downloaded Pair (Fire: 2024-10-22 | Normal: 2023-10-10)
# Saved: fire_12056_2024-04-27.png
# Saved: normal_12056_2023-04-21.png
# [12056] Downloaded Pair (Fire: 2024-04-27 | Normal: 2023-04-21)
# Saved: fire_12057_2024-08-05.png
# Saved: normal_12057_2023-07-24.png
# [12057] Downloaded Pair (Fire: 2024-08-05 | Normal: 2023-07-24)
# Saved: fire_12058_2024-08-31.png
# Saved: normal_12058_2023-08-18.png
# [12058] Downloaded Pair (Fire: 2024-08-31 | Normal: 2023-08-18)
# Saved: fire_12059_2024-06-06.png
# Saved: normal_12059_2023-05-24.png
# [12059] Downloaded Pair (Fire: 2024-06-06 | Normal: 2023-05-24)
# Saved: fire_12060_2024-06-17.png
# Saved: normal_12060_2023-06-05.png
# [12060] Downloaded Pair (Fire: 2024-06-17 | Normal: 2023-06-05)
# Saved: fire_12061_2024-10-13.png
# Saved: normal_12061_2023-10-12.png
# [12061] Downloaded Pair (Fire: 2024-10-13 | Normal: 2023-10-12)
# Saved: fire_12062_2024-09-12.png
# Saved: normal_12062_2023-09-05.png
# [12062] Downloaded Pair (Fire: 2024-09-12 | Normal: 2023-09-05)
# Saved: fire_12063_2024-12-01.png
# [12063] Skipped Normal: Too cloudy
# Saved: fire_12064_2024-10-17.png
# Saved: normal_12064_2023-10-04.png
# [12064] Downloaded Pair (Fire: 2024-10-17 | Normal: 2023-10-04)
# Saved: fire_12065_2024-11-07.png
# [12065] Skipped Normal: Too cloudy
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_12066_2023-09-08.png
# [12066] Downloaded Pair (Fire: 2024-09-21 | Normal: 2023-09-08)
# Download Error: HTTPSConnectionPool(host='earthengine.googleapis.com', port=443): Read timed out. (read timeout=1)
# Saved: normal_12067_2023-08-17.png
# [12067] Downloaded Pair (Fire: 2024-08-28 | Normal: 2023-08-17)
# Saved: fire_12068_2024-09-19.png
# Saved: normal_12068_2023-09-11.png
# [12068] Downloaded Pair (Fire: 2024-09-19 | Normal: 2023-09-11)
# Saved: fire_12069_2024-09-12.png
# Saved: normal_12069_2023-08-31.png
# [12069] Downloaded Pair (Fire: 2024-09-12 | Normal: 2023-08-31)
# Saved: fire_12070_2024-09-17.png
# Saved: normal_12070_2023-09-05.png
# [12070] Downloaded Pair (Fire: 2024-09-17 | Normal: 2023-09-05)
# Saved: fire_12071_2024-03-17.png
# [12071] Skipped Normal: Too cloudy
# Saved: fire_12072_2024-08-29.png
# Saved: normal_12072_2023-08-16.png
# [12072] Downloaded Pair (Fire: 2024-08-29 | Normal: 2023-08-16)
# Saved: fire_12073_2024-12-13.png
#
# Stopping download...
#
# Session Finished.
# New Fire Images: 5336
# New Normal Images: 5074

# %%
# !zip -r modis_dataset_brazil.zip /content/modis_dataset_brazil

# %%
import shutil
# shutil.rmtree("/content/modis_dataset")
